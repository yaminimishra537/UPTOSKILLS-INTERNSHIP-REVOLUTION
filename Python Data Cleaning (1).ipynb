# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Uptoskills/Corporate Dataset.csv"
df = pd.read_csv(path, encoding='ISO-8859-1')
df.head(0)    # used for only viewing the Columns
# Out:
# Empty DataFrame
# Columns: [Company Name, Source / Website Link, Contact Number, Contact Person / Name of HR, Email ID, Designation, Location, State, Internship(Paid) / Job, On- Site / Remote / Hybrid, Unnamed: 10, Unnamed: 11]
# Index: []

# %%
df.shape   # for seeing Columns and rows
# Out:
# (4039, 12)

# %%
df.isnull()
# Out:
#       Company Name  Source / Website Link  Contact Number  \
# 0            False                  False           False
# 1            False                  False           False
# 2            False                  False           False
# 3            False                  False           False
# 4            False                  False           False
# ...            ...                    ...             ...
# 4034         False                  False           False
# 4035         False                  False           False
# 4036         False                  False           False
# 4037         False                  False           False
# 4038         False                  False           False
#
#       Contact Person / Name of HR  Email ID  Designation  Location  State  \
# 0                           False     False        False     False  False
# 1                           False     False        False     False  False
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                    253
# Source / Website Link           289
# Contact Number                  406
# Contact Person / Name of HR     278
# Email ID                        337
# Designation                     254
# Location                        253
# State                           253
# Internship(Paid) / Job          257
# On- Site / Remote / Hybrid      284
# Unnamed: 10                    4039
# Unnamed: 11                    4039
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(10942)

# %%
df.isnull().sum()/(df.shape[0]*df.shape[1])*100   # df.isnull() for True and False, .sum() for total, df.shape[0] = number of rows df.shape[1] = number of columns Their product = total cells in the table
# Out:
# Company Name                   0.521994
# Source / Website Link          0.596270
# Contact Number                 0.837666
# Contact Person / Name of HR    0.573574
# Email ID                       0.695304
# Designation                    0.524057
# Location                       0.521994
# State                          0.521994
# Internship(Paid) / Job         0.530247
# On- Site / Remote / Hybrid     0.585954
# Unnamed: 10                    8.333333
# Unnamed: 11                    8.333333
# dtype: float64

# %%
sns.heatmap(df.isnull())   # this is used in seaborn, white lines are the null values and rest are not null
plt.show()

# %%
df.isnull().sum()
# Out:
# Company Name                    253
# Source / Website Link           289
# Contact Number                  406
# Contact Person / Name of HR     278
# Email ID                        337
# Designation                     254
# Location                        253
# State                           253
# Internship(Paid) / Job          257
# On- Site / Remote / Hybrid      284
# Unnamed: 10                    4039
# Unnamed: 11                    4039
# dtype: int64

# %%
df.drop(columns=['Unnamed: 10', 'Unnamed: 11'], inplace=True)   # use ",inplace=True" for removing columns from existing dataset

# %%
df.notnull().sum()
# Out:
# Company Name                   3786
# Source / Website Link          3750
# Contact Number                 3633
# Contact Person / Name of HR    3761
# Email ID                       3702
# Designation                    3785
# Location                       3786
# State                          3786
# Internship(Paid) / Job         3782
# On- Site / Remote / Hybrid     3755
# dtype: int64

# %%
df.dropna(axis= 0 , inplace= True)

# %%
row_count = len(df.dropna())
row_count
# Out:
# 3486

# %%
df.isnull().sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
sns.heatmap(df.isnull())   # this is used in seaborn, white lines are the null values and rest are not null
plt.show()

# %%
df.head()
# Out:
#                          Company Name  \
# 0  INSOMNIACS DIGITAL PRIVATE LIMITED
# 1                            Concorde
# 2                    Nous Infosystems
# 3                        Team pumpkin
# 4                 Stalwarts Servicios
#
#                                Source / Website Link Contact Number  \
# 0  https://in.indeed.com/q-media-l-bengaluru,-kar...    88886 99987
# 1  https://in.indeed.com/viewjob?jk=e5bbb50a57e1b...    78 29959921
# 2  https://in.indeed.com/q-media-l-bengaluru,-kar...   80-2532 9797
# 3  https://in.indeed.com/q-media-l-bengaluru,-kar...    7761 968718
# 4  https://in.indeed.com/q-media-l-bengaluru,-kar...    96007 87772
#
#   Contact Person / Name of HR                     Email ID  \
# 0                     COMPANY           info@insomniacs.in
# 1                     COMPANY        marketing@concorde.in
# 2                     COMPANY        accounts@nousinfo.com
# 3                     COMPANY          connect@teampumpkin
# ...

# %%
df.isin(["NIL"]).stack()[lambda x: x].index.tolist()   # need to check this
# Out:
# [(3843, 'Contact Number'),
#  (3843, 'Email ID'),
#  (3844, 'Contact Number'),
#  (3844, 'Email ID'),
#  (3845, 'Contact Number'),
#  (3845, 'Email ID'),
#  (3846, 'Contact Number'),
#  (3846, 'Email ID'),
#  (3847, 'Contact Number'),
#  (3847, 'Email ID'),
#  (3848, 'Contact Number'),
#  (3848, 'Email ID'),
#  (3849, 'Contact Number'),
#  (3849, 'Email ID'),
#  (3850, 'Contact Number'),
#  (3850, 'Email ID'),
#  (3851, 'Contact Number'),
#  (3851, 'Email ID'),
#  (3852, 'Contact Number'),
#  (3852, 'Email ID')]

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["na"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                 False
# Contact Person / Name of HR    False
# Email ID                       False
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["NA"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                 False
# Contact Person / Name of HR    False
# Email ID                       False
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["N/A"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                 False
# Contact Person / Name of HR    False
# Email ID                       False
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["-"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                  True
# Contact Person / Name of HR     True
# Email ID                        True
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid      True
# dtype: bool

# %%
(df == "-").sum().sum() # total - value
# Out:
# np.int64(54)

# %%
(df == "-").sum()  # total - values in each columns
# Out:
# Company Name                    0
# Source / Website Link           0
# Contact Number                 35
# Contact Person / Name of HR     2
# Email ID                       16
# Designation                     0
# Location                        0
# State                           0
# Internship(Paid) / Job          0
# On- Site / Remote / Hybrid      1
# dtype: int64

# %%
count_rows_with_dash = df[df.eq("-").any(axis=1)].shape[0]
print("Total rows containing at least one '-' :", count_rows_with_dash)
# Out:
# Total rows containing at least one '-' : 48

# %%
df[df.eq("-").any(axis=1)].count()    # Rows which have "-"
# Out:
# Company Name                   48
# Source / Website Link          48
# Contact Number                 48
# Contact Person / Name of HR    48
# Email ID                       48
# Designation                    48
# Location                       48
# State                          48
# Internship(Paid) / Job         48
# On- Site / Remote / Hybrid     48
# dtype: int64

# %%
df[df.eq("-").any(axis=1)]    # View rows that contain at least one "-" :: df.eq("-"): same as df == "-", returns True where value is exactly "-"
                              # .any(axis=1): checks if any column in the row has "-"
                              # df[...]: filters and returns those rows
# Out:
#                              Company Name  \
# 242   Newgen Material Handling Equipments
# 245                        Five S Digital
# 246              VLCC Healthcare Pvt. Ltd
# 247                      Srikara Builders
# 248                             IntouchCX
# 272                               Infosys
# 273                         Tech Mahindra
# 274                         JPMorganChase
# 276                                 Adobe
# 277                                 Wipro
# 281                                   IBM
# 312                      Raasoft Infotech
# 316                                 ICICI
# 318                       Reliance Retail
# 474                            Ruia Group
# 475                            KocharTech
# 476              Zacks Research Pvt. Ltd.
# 478            Skillsonics India Pvt. Ltd
# 479                             Adlib LLP
# 820                               Genpact
# 831                  VIDYAOne IT Solution
# ...

# %%
df.replace('-', np.nan, inplace=True)

# %%
df[df.eq("-").any(axis=1)]    # View rows that contain at least one "-" :: df.eq("-"): same as df == "-", returns True where value is exactly "-"
                              # .any(axis=1): checks if any column in the row has "-"
                              # df[...]: filters and returns those rows
# Out:
# Empty DataFrame
# Columns: [Company Name, Source / Website Link, Contact Number, Contact Person / Name of HR, Email ID, Designation, Location, State, Internship(Paid) / Job, On- Site / Remote / Hybrid]
# Index: []

# %%
(df == "-").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
row_count = len(df)
row_count
# Out:
# 3486

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["NIL"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                  True
# Contact Person / Name of HR    False
# Email ID                        True
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
(df == "NIL").sum().sum()  # total NIL values
# Out:
# np.int64(20)

# %%
(df == "NIL").sum()  # total NIL values in columns
# Out:
# Company Name                    0
# Source / Website Link           0
# Contact Number                 10
# Contact Person / Name of HR     0
# Email ID                       10
# Designation                     0
# Location                        0
# State                           0
# Internship(Paid) / Job          0
# On- Site / Remote / Hybrid      0
# dtype: int64

# %%
count_rows_with_NIL_Values = df[df.eq("NIL").any(axis=1)].shape[0]
print("Total rows containing at least one 'NIL' :", count_rows_with_NIL_Values)
# Out:
# Total rows containing at least one 'NIL' : 10

# %%
df[df.eq("NIL").any(axis=1)].count()   # rows which have "NIL"
# Out:
# Company Name                   10
# Source / Website Link          10
# Contact Number                 10
# Contact Person / Name of HR    10
# Email ID                       10
# Designation                    10
# Location                       10
# State                          10
# Internship(Paid) / Job         10
# On- Site / Remote / Hybrid     10
# dtype: int64

# %%
df[df.eq("NIL").any(axis=1)]
# Out:
#                             Company Name  \
# 3843                           MICROSOFT
# 3844                           MICROSOFT
# 3845         STEEL STRIPS WHEELS LIMITED
# 3846  FRANKFINN AVIATION SERVICE PVT.LTD
# 3847             HANNA INSTRUMENTS INDIA
# 3848                          KPMG INDIA
# 3849                   COLGATE-PALMOLIVE
# 3850                     REVINFOTECH INC
# 3851                           SKILLLABS
# 3852             HANNA INSTRUMENTS INDIA
#
#                                   Source / Website Link Contact Number  \
# 3843  https://in.linkedin.com/jobs/view/software-eng...            NIL
# 3844  https://in.linkedin.com/jobs/view/consultant-b...            NIL
# 3845  https://in.linkedin.com/jobs/view/dispatch-sup...            NIL
# 3846  https://in.linkedin.com/jobs/view/training-coo...            NIL
# 3847  https://in.linkedin.com/jobs/view/technical-sa...            NIL
# 3848  https://in.linkedin.com/jobs/view/government-p...            NIL
# ...

# %%
df.replace('NIL', np.nan, inplace=True)

# %%
(df == "NIL").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
row_count = len(df)
row_count
# Out:
# 3486

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["NL"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                  True
# Contact Person / Name of HR     True
# Email ID                        True
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
(df == "NL").sum().sum()
# Out:
# np.int64(22)

# %%
(df == "NL").sum()
# Out:
# Company Name                    0
# Source / Website Link           0
# Contact Number                  6
# Contact Person / Name of HR     2
# Email ID                       14
# Designation                     0
# Location                        0
# State                           0
# Internship(Paid) / Job          0
# On- Site / Remote / Hybrid      0
# dtype: int64

# %%
count_rows_with_NL_Values = df[df.eq("NIL").any(axis=1)].shape[0]
print("Total rows containing at least one 'NIL' :", count_rows_with_NL_Values)
# Out:
# Total rows containing at least one 'NIL' : 0

# %%
df[df.eq("NL").any(axis=1)].count()
# Out:
# Company Name                   17
# Source / Website Link          17
# Contact Number                 17
# Contact Person / Name of HR    17
# Email ID                       17
# Designation                    17
# Location                       17
# State                          17
# Internship(Paid) / Job         17
# On- Site / Remote / Hybrid     17
# dtype: int64

# %%
df[df.eq("NL").any(axis=1)]
# Out:
#                                          Company Name  \
# 60                                ESS ELL Diagnsotics
# 61                           EASTMAN CAST & FORGE LTD
# 359                                         Adlib LLP
# 360                                 TEN :- Healthcare
# 370                     Devant IT Solutions Pvt. Ltd.
# 680                          Amfill Digital Solutions
# 1589  SP BEVCODE CONSULTANCY SERVICES PRIVATE LIMITED
# 1590                    Triveni Interchem Pvt.Limited
# 1593                                         Deloitte
# 1594                                    SARA INFOTECH
# 1710                                 Nation With NaMo
# 2265                              Vedantu Innovations
# 2266                                         Oakridge
# 2858                       Polar Power And Automation
# 3062                              Vedantu Innovations
# 3063                                         Oakridge
# ...

# %%
df.replace('NL', np.nan, inplace=True)

# %%
(df == "NL").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
row_count = len(df)
row_count
# Out:
# 3486

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["not found"]).any()
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                  True
# Contact Person / Name of HR    False
# Email ID                        True
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
(df == "not found").sum().sum()
# Out:
# np.int64(11)

# %%
(df == "not found").sum()
# Out:
# Company Name                    0
# Source / Website Link           0
# Contact Number                 10
# Contact Person / Name of HR     0
# Email ID                        1
# Designation                     0
# Location                        0
# State                           0
# Internship(Paid) / Job          0
# On- Site / Remote / Hybrid      0
# dtype: int64

# %%
count_rows_with_not_found = df[df.eq("not found").any(axis=1)].shape[0]
print("Total rows containing at least one 'not found' :", count_rows_with_not_found)
# Out:
# Total rows containing at least one 'not found' : 11

# %%
df[df.eq("not found").any(axis=1)].count()
# Out:
# Company Name                   11
# Source / Website Link          11
# Contact Number                 11
# Contact Person / Name of HR    11
# Email ID                       11
# Designation                    11
# Location                       11
# State                          11
# Internship(Paid) / Job         11
# On- Site / Remote / Hybrid     10
# dtype: int64

# %%
df[df.eq("not found").any(axis=1)]
# Out:
#               Company Name                              Source / Website Link  \
# 269         Intelli Search  https://www.naukri.com/job-listings-ca-finance...
# 427                    G4S                                           LinkedIn
# 428                   HSBC                                            LinkdIn
# 430   Foxhog Ventures Corp                                            LinkdIn
# 3489    NeerInfo Solutions                                            LinkdIn
# 3490              Deloitte                                            LinkdIn
# 3493           LeewayHertz                                            LinkdIn
# 3494                 Wipro                                           LinkedIn
# 3495             PINKERTON                                            LinkdIn
# 3496          SalesCode.ai                                            LinkdIn
# 3497           VerbaFlo.AI                                            LinkdIn
#
# ...

# %%
df.replace('not found', np.nan, inplace=True)

# %%
row_count = len(df)
row_count
# Out:
# 3486

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["nil"]).any()  ### later
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                  True
# Contact Person / Name of HR     True
# Email ID                        True
# Designation                     True
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
(df == "nil").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 1
# Contact Person / Name of HR    4
# Email ID                       2
# Designation                    4
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
df.replace('nil', np.nan, inplace=True)

# %%
row_count = len(df)
row_count
# Out:
# 3486

# %%
df[["Company Name", "Source / Website Link", "Contact Number",
    "Contact Person / Name of HR", "Email ID", "Designation",
    "Location", "State", "Internship(Paid) / Job", "On- Site / Remote / Hybrid"]].isin(["Not Available"]).any() ## later
# Out:
# Company Name                   False
# Source / Website Link          False
# Contact Number                 False
# Contact Person / Name of HR    False
# Email ID                        True
# Designation                    False
# Location                       False
# State                          False
# Internship(Paid) / Job         False
# On- Site / Remote / Hybrid     False
# dtype: bool

# %%
(df == "Not Available").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       1
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
df.replace('Not Available', np.nan, inplace=True)

# %%
df.replace('Not found', np.nan, inplace=True)

# %%
df.replace('not found', np.nan, inplace=True)

# %%
df.replace('Not Found', np.nan, inplace=True)

# %%
(df == "-").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "Nil").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "nil").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "NL").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "not found").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "Not found").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "Not Available").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
(df == "not available").sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       4
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
df.replace('not available', np.nan, inplace=True)

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
row_count = len(df)
row_count
# Out:
# 3378

# %%
for i in df.select_dtypes(include="object").columns:
    df[i].fillna(df[i].mode()[0], inplace=True)
# Out:
# <ipython-input-81-5ca14513a4a3>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0], inplace=True)

# %%
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Company Name                   0
# Source / Website Link          0
# Contact Number                 0
# Contact Person / Name of HR    0
# Email ID                       0
# Designation                    0
# Location                       0
# State                          0
# Internship(Paid) / Job         0
# On- Site / Remote / Hybrid     0
# dtype: int64

# %%
row_count = len(df)
row_count
# Out:
# 3378

# %%
duplicates = df[df.duplicated(keep=False)]
print(duplicates)
# Out:
#                             Company Name  \
# 604                    Chhanv Foundation
# 610                    Chhanv Foundation
# 973        IFW Techno Creations Pvt. Ltd
# 976                   Hourly Hotel Deals
# 982                   Hourly Hotel Deals
# ...                                  ...
# 4034             Qtonix software pvt ltd
# 4035                      find next hire
# 4036                           protrainy
# 4037  Khimji dayabhai group of companies
# 4038                               River
#
#                                   Source / Website Link Contact Number  \
# 604   https://in.indeed.com/q-social-worker-%2C-msw%...     9717900302
# 610   https://in.indeed.com/q-social-worker-%2C-msw%...     9717900302
# 973   https://in.indeed.com/viewjob?jk=1d5704e3c3eba...    93144 09691
# 976   https://in.indeed.com/viewjob?jk=44414ae2cbbfa...     7878989812
# 982   https://in.indeed.com/viewjob?jk=44414ae2cbbfa...     7878989812
# ...

# %%
df.duplicated(keep=False).sum()
# Out:
# np.int64(760)

# %%
df.duplicated(keep=False).sum().sum()
# Out:
# np.int64(760)

# %%
df.head(20)
# Out:
#                           Company Name  \
# 0   INSOMNIACS DIGITAL PRIVATE LIMITED
# 1                             Concorde
# 2                     Nous Infosystems
# 3                         Team pumpkin
# 4                  Stalwarts Servicios
# 5                            Supercode
# 8                             ABC Corp
# 9   Kaveri Plasto Containers Pvt. Ltd.
# 10                              Corizo
# 11                     INDIGO INTERIOR
# 12     Performance Marketing Executive
# 13             Games Marketing Manager
# 14                          MediaJenie
# 15                   Whitespace Global
# 16         Trasol Technologies Pvt Ltd
# 17                              Swiggy
# 20                         Halliburton
# 21                  Accenture in India
# 22                        Senso Vision
# 23         Quoqo Technologies (P) Ltd.
#
#                                 Source / Website Link  \
# 0   https://in.indeed.com/q-media-l-bengaluru,-kar...
# ...

# %%
df.shape
# Out:
# (3378, 10)

# %%
df.to_csv('Corporate Dataset.csv', index=False)  # for j

# %%
from google.colab import files
files.download('Corporate Dataset.csv')  # or 'cleaned_data.xlsx'

# %%
# Replace anything in 'contact' that doesn't contain 'company' (case-insensitive) with 'hr'
df['Contact Person'] = df['Contact Person / Name of HR'].apply(lambda x: x if 'company' in str(x).lower() else 'hr')

# %%
df.head(50)
# Out:
#                           Company Name  \
# 0   INSOMNIACS DIGITAL PRIVATE LIMITED
# 1                             Concorde
# 2                     Nous Infosystems
# 3                         Team pumpkin
# 4                  Stalwarts Servicios
# 5                            Supercode
# 8                             ABC Corp
# 9   Kaveri Plasto Containers Pvt. Ltd.
# 10                              Corizo
# 11                     INDIGO INTERIOR
# 12     Performance Marketing Executive
# 13             Games Marketing Manager
# 14                          MediaJenie
# 15                   Whitespace Global
# 16         Trasol Technologies Pvt Ltd
# 17                              Swiggy
# 20                         Halliburton
# 21                  Accenture in India
# 22                        Senso Vision
# 23         Quoqo Technologies (P) Ltd.
# 24                     Larsen & Toubro
# 25             Divya Staffing Solution
# 26                             Techzen
# ...

# %%
# Find duplicate rows (including all occurrences)
duplicates = df[df.duplicated(keep=False)]
print("All Duplicate Rows:")
print(duplicates)

# Remove duplicates but keep one of each
df_unique = df.drop_duplicates(keep='first')

print("\nDataFrame after removing duplicates (keeping first occurrence):")
print(df_unique)
# Out:
# All Duplicate Rows:
#                             Company Name  \
# 604                    Chhanv Foundation
# 610                    Chhanv Foundation
# 973        IFW Techno Creations Pvt. Ltd
# 976                   Hourly Hotel Deals
# 982                   Hourly Hotel Deals
# ...                                  ...
# 4034             Qtonix software pvt ltd
# 4035                      find next hire
# 4036                           protrainy
# 4037  Khimji dayabhai group of companies
# 4038                               River
#
#                                   Source / Website Link Contact Number  \
# 604   https://in.indeed.com/q-social-worker-%2C-msw%...     9717900302
# 610   https://in.indeed.com/q-social-worker-%2C-msw%...     9717900302
# 973   https://in.indeed.com/viewjob?jk=1d5704e3c3eba...    93144 09691
# 976   https://in.indeed.com/viewjob?jk=44414ae2cbbfa...     7878989812
# 982   https://in.indeed.com/viewjob?jk=44414ae2cbbfa...     7878989812
# ...

# %%
df_unique = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (3378, 11)
